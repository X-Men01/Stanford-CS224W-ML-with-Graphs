# %%
import pandas as pd
import numpy as np
import torch
import networkx as nx
from sklearn.preprocessing import StandardScaler, LabelEncoder
from torch_geometric.data import Data
from torch_geometric.utils import from_networkx
import matplotlib.pyplot as plt

# %%
from torch_geometric.data import Data
from sklearn.preprocessing import StandardScaler
import numpy as np
import torch



preprocessed_data = pd.read_csv("/Users/ahmedalkhulayfi/Documents/Stanford/Labs/project/preprocessed_data.csv")

# Step 1: Prepare features and labels
X = preprocessed_data.drop(columns=["Target_encoded"]).values  # Features
y = preprocessed_data["Target_encoded"].values  # Labels

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert features and labels to PyTorch tensors
node_features = torch.tensor(X_scaled, dtype=torch.float)
node_labels = torch.tensor(y, dtype=torch.long)


# Identify the source columns
source_cols = [col for col in preprocessed_data.columns if col.startswith("Source_")]

edges = []
for i in range(len(preprocessed_data)):
    # Extract the source pattern for node i
    source_i = preprocessed_data.iloc[i][source_cols].values
    cip_i = preprocessed_data.iloc[i]["Target_encoded"]
    
    # The argmax will give the index of the '1' in the one-hot encoding
    source_i_idx = source_i.argmax()

    for j in range(i + 1, len(preprocessed_data)):
        source_j = preprocessed_data.iloc[j][source_cols].values
        cip_j = preprocessed_data.iloc[j]["Target_encoded"]
        source_j_idx = source_j.argmax()

        # Check same source and CIP equality
        if source_i_idx == source_j_idx and cip_i == cip_j:
            edges.append((i, j))

            
# Step 3: Create the PyTorch Geometric Data object
edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous()
print("edge_index shape:", edge_index.shape)
print("edge_index dtype:", edge_index.dtype)
print(node_features.shape)
data = Data(x=node_features, edge_index=edge_index, y=node_labels)
print(edges)

# preprocessed_data["CIP_numeric"]
# Out:
# edge_index shape: torch.Size([2, 3343])
# edge_index dtype: torch.int64
# torch.Size([261, 28])
# [(0, 1), (0, 11), (0, 12), (0, 13), (0, 14), (0, 15), (0, 16), (0, 17), (0, 18), (0, 19), (0, 20), (0, 21), (0, 26), (0, 27), (0, 34), (0, 47), (0, 48), (0, 49), (0, 50), (0, 52), (0, 63), (0, 64), (0, 65), (0, 66), (0, 68), (0, 70), (0, 72), (0, 79), (0, 80), (0, 81), (0, 82), (0, 83), (0, 124), (0, 125), (0, 126), (0, 251), (0, 252), (0, 253), (0, 254), (0, 255), (0, 256), (0, 257), (0, 258), (0, 259), (0, 260), (1, 11), (1, 12), (1, 13), (1, 14), (1, 15), (1, 16), (1, 17), (1, 18), (1, 19), (1, 20), (1, 21), (1, 26), (1, 27), (1, 34), (1, 47), (1, 48), (1, 49), (1, 50), (1, 52), (1, 63), (1, 64), (1, 65), (1, 66), (1, 68), (1, 70), (1, 72), (1, 79), (1, 80), (1, 81), (1, 82), (1, 83), (1, 124), (1, 125), (1, 126), (1, 251), (1, 252), (1, 253), (1, 254), (1, 255), (1, 256), (1, 257), (1, 258), (1, 259), (1, 260), (2, 25), (2, 55), (2, 73), (2, 74), (2, 75), (2, 76), (2, 77), (2, 78), (2, 85), (2, 86), (2, 87), (2, 99), (2, 105), (2, 109), (2, 112), (2, 127), (2, 128), (2, 129), (2, 142), (3, 22), (3, 23), (3, 24), (3, 28), (3, 29), (3, 35), (3, 36), (3, 37), (3, 56), (3, 57), (3, 88), (3, 89), (3, 90), (3, 91), (3, 92), (3, 93), (3, 94), (3, 95), (3, 96), (3, 97), (3, 98), (3, 100), (3, 104), (3, 106), (3, 108), (3, 110), (3, 130), (4, 5), (4, 46), (4, 54), (5, 46), (5, 54), (6, 32), (7, 8), (7, 9), (8, 9), (10, 122), (11, 12), (11, 13), (11, 14), (11, 15), (11, 16), (11, 17), (11, 18), (11, 19), (11, 20), (11, 21), (11, 26), (11, 27), (11, 34), (11, 47), (11, 48), (11, 49), (11, 50), (11, 52), (11, 63), (11, 64), (11, 65), (11, 66), (11, 68), (11, 70), (11, 72), (11, 79), (11, 80), (11, 81), (11, 82), (11, 83), (11, 124), (11, 125), (11, 126), (11, 251), (11, 252), (11, 253), (11, 254), (11, 255), (11, 256), (11, 257), (11, 258), (11, 259), (11, 260), (12, 13), (12, 14), (12, 15), (12, 16), (12, 17), (12, 18), (12, 19), (12, 20), (12, 21), (12, 26), (12, 27), (12, 34), (12, 47), (12, 48), (12, 49), (12, 50), (12, 52), (12, 63), (12, 64), (12, 65), (12, 66), (12, 68), (12, 70), (12, 72), (12, 79), (12, 80), (12, 81), (12, 82), (12, 83), (12, 124), (12, 125), (12, 126), (12, 251), (12, 252), (12, 253), (12, 254), (12, 255), (12, 256), (12, 257), (12, 258), (12, 259), (12, 260), (13, 14), (13, 15), (13, 16), (13, 17), (13, 18), (13, 19), (13, 20), (13, 21), (13, 26), (13, 27), (13, 34), (13, 47), (13, 48), (13, 49), (13, 50), (13, 52), (13, 63), (13, 64), (13, 65), (13, 66), (13, 68), (13, 70), (13, 72), (13, 79), (13, 80), (13, 81), (13, 82), (13, 83), (13, 124), (13, 125), (13, 126), (13, 251), (13, 252), (13, 253), (13, 254), (13, 255), (13, 256), (13, 257), (13, 258), (13, 259), (13, 260), (14, 15), (14, 16), (14, 17), (14, 18), (14, 19), (14, 20), (14, 21), (14, 26), (14, 27), (14, 34), (14, 47), (14, 48), (14, 49), (14, 50), (14, 52), (14, 63), (14, 64), (14, 65), (14, 66), (14, 68), (14, 70), (14, 72), (14, 79), (14, 80), (14, 81), (14, 82), (14, 83), (14, 124), (14, 125), (14, 126), (14, 251), (14, 252), (14, 253), (14, 254), (14, 255), (14, 256), (14, 257), (14, 258), (14, 259), (14, 260), (15, 16), (15, 17), (15, 18), (15, 19), (15, 20), (15, 21), (15, 26), (15, 27), (15, 34), (15, 47), (15, 48), (15, 49), (15, 50), (15, 52), (15, 63), (15, 64), (15, 65), (15, 66), (15, 68), (15, 70), (15, 72), (15, 79), (15, 80), (15, 81), (15, 82), (15, 83), (15, 124), (15, 125), (15, 126), (15, 251), (15, 252), (15, 253), (15, 254), (15, 255), (15, 256), (15, 257), (15, 258), (15, 259), (15, 260), (16, 17), (16, 18), (16, 19), (16, 20), (16, 21), (16, 26), (16, 27), (16, 34), (16, 47), (16, 48), (16, 49), (16, 50), (16, 52), (16, 63), (16, 64), (16, 65), (16, 66), (16, 68), (16, 70), (16, 72), (16, 79), (16, 80), (16, 81), (16, 82), (16, 83), (16, 124), (16, 125), (16, 126), (16, 251), (16, 252), (16, 253), (16, 254), (16, 255), (16, 256), (16, 257), (16, 258), (16, 259), (16, 260), (17, 18), (17, 19), (17, 20), (17, 21), (17, 26), (17, 27), (17, 34), (17, 47), (17, 48), (17, 49), (17, 50), (17, 52), (17, 63), (17, 64), (17, 65),  ...

# %%
preprocessed_data.columns
# Out:
# Index(['Sample_FC', 'Sample_FCS', 'Sample_FFC', 'Sample_PC', 'Source_A',
#        'Source_B', 'Source_C', 'Source_D', 'Source_E', 'Source_F', 'Source_H',
#        'Source_I', 'Source_J', 'Source_K', 'Source_L', 'Source_M', 'Source_N',
#        'Source_O', 'Source_P', 'Source_Q', 'Source_Unknown', 'AMI_symbol_I',
#        'AMI_symbol_S', 'AMP_numeric', 'AMP_special_case', 'AMP_symbol_R',
#        'AMP_symbol_S', 'CIP_numeric', 'Target_encoded'],
#       dtype='object')

# %%
# Define train/test/val masks
torch.manual_seed(4)
num_nodes = data.num_nodes
train_ratio, val_ratio, test_ratio = 0.7, 0.1, 0.2

# Randomly shuffle nodes
indices = torch.randperm(num_nodes)
train_size = int(train_ratio * num_nodes)
val_size = int(val_ratio * num_nodes)

train_mask = torch.zeros(num_nodes, dtype=torch.bool)
val_mask = torch.zeros(num_nodes, dtype=torch.bool)
test_mask = torch.zeros(num_nodes, dtype=torch.bool)

train_mask[indices[:train_size]] = True
val_mask[indices[train_size:train_size + val_size]] = True
test_mask[indices[train_size + val_size:]] = True

# Add masks to the data object
data.train_mask = train_mask
data.val_mask = val_mask
data.test_mask = test_mask

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv

class GCN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GCN, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, output_dim)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index  # Node features and edges
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)  # Log-softmax for classification

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data = data.to(device)

# Hyperparameters
input_dim = data.num_node_features
hidden_dim = 16
output_dim = len(torch.unique(data.y))
learning_rate = 0.01
weight_decay = 5e-4
max_epochs = 1000
patience = 50

model = GCN(input_dim, hidden_dim, output_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Add LR Cosine Annealing
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max_epochs)

criterion = torch.nn.CrossEntropyLoss()

def evaluate(model, data, mask):
    model.eval()
    with torch.no_grad():
        out = model(data)
        loss = criterion(out[mask], data.y[mask])
        preds = out[mask].argmax(dim=1)
        accuracy = (preds == data.y[mask]).sum().item() / mask.sum().item()
    return loss.item(), accuracy

best_val_loss = float('inf')
epochs_no_improve = 0

for epoch in range(max_epochs):
    model.train()
    optimizer.zero_grad()
    out = model(data)
    train_loss = criterion(out[data.train_mask], data.y[data.train_mask])
    train_loss.backward()
    optimizer.step()

    # Step the scheduler after optimizer step
    scheduler.step()

    # Evaluate on validation set
    val_loss, val_accuracy = evaluate(model, data, data.val_mask)

    # Early stopping logic
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_no_improve = 0
        best_model_state = model.state_dict()
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print("Early stopping triggered!")
            break

    if epoch % 10 == 0:
        train_preds = out[data.train_mask].argmax(dim=1)
        train_accuracy = (train_preds == data.y[data.train_mask]).sum().item() / data.train_mask.sum().item()
        current_lr = scheduler.get_last_lr()[0]
        print(
            f"Epoch: {epoch}, LR: {current_lr:.6f}, "
            f"Train Loss: {train_loss.item():.4f}, Train Acc: {train_accuracy:.4f}, "
            f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}"
        )

# Load the best model state
model.load_state_dict(best_model_state)
# Out:
# Epoch: 0, LR: 0.010000, Train Loss: 2.2227, Train Acc: 0.4066, Val Loss: 2.0755, Val Acc: 0.3846
# Epoch: 10, LR: 0.009997, Train Loss: 0.5990, Train Acc: 0.7857, Val Loss: 0.5897, Val Acc: 0.8462
# Epoch: 20, LR: 0.009989, Train Loss: 0.3936, Train Acc: 0.8297, Val Loss: 0.4350, Val Acc: 0.8462
# Epoch: 30, LR: 0.009976, Train Loss: 0.3353, Train Acc: 0.8956, Val Loss: 0.4460, Val Acc: 0.8462
# Epoch: 40, LR: 0.009959, Train Loss: 0.2904, Train Acc: 0.9011, Val Loss: 0.4530, Val Acc: 0.8462
# Epoch: 50, LR: 0.009936, Train Loss: 0.2469, Train Acc: 0.9231, Val Loss: 0.4045, Val Acc: 0.8462
# Epoch: 60, LR: 0.009908, Train Loss: 0.2093, Train Acc: 0.9451, Val Loss: 0.3774, Val Acc: 0.8462
# Epoch: 70, LR: 0.009876, Train Loss: 0.1770, Train Acc: 0.9615, Val Loss: 0.3539, Val Acc: 0.8462
# Epoch: 80, LR: 0.009839, Train Loss: 0.1482, Train Acc: 0.9615, Val Loss: 0.3188, Val Acc: 0.8846
# Epoch: 90, LR: 0.009797, Train Loss: 0.1227, Train Acc: 0.9615, Val Loss: 0.2937, Val Acc: 0.8846
# Epoch: 100, LR: 0.009750, Train Loss: 0.1035, Train Acc: 0.9615, Val Loss: 0.2721, Val Acc: 0.8846
# Epoch: 110, LR: 0.009699, Train Loss: 0.0883, Train Acc: 0.9615, Val Loss: 0.2534, Val Acc: 0.9231
# Epoch: 120, LR: 0.009643, Train Loss: 0.0752, Train Acc: 0.9780, Val Loss: 0.2377, Val Acc: 0.9231
# Epoch: 130, LR: 0.009583, Train Loss: 0.0643, Train Acc: 0.9890, Val Loss: 0.2247, Val Acc: 0.9231
# Epoch: 140, LR: 0.009517, Train Loss: 0.0546, Train Acc: 0.9945, Val Loss: 0.2118, Val Acc: 0.9231
# Epoch: 150, LR: 0.009448, Train Loss: 0.0459, Train Acc: 0.9945, Val Loss: 0.2007, Val Acc: 0.9615
# Epoch: 160, LR: 0.009374, Train Loss: 0.0399, Train Acc: 0.9945, Val Loss: 0.1910, Val Acc: 0.9615
# Epoch: 170, LR: 0.009296, Train Loss: 0.0350, Train Acc: 1.0000, Val Loss: 0.1845, Val Acc: 0.9615
# Epoch: 180, LR: 0.009213, Train Loss: 0.0309, Train Acc: 1.0000, Val Loss: 0.1808, Val Acc: 0.9615
# Epoch: 190, LR: 0.009127, Train Loss: 0.0275, Train Acc: 1.0000, Val Loss: 0.1779, Val Acc: 0.9615
# Epoch: 200, LR: 0.009036, Train Loss: 0.0248, Train Acc: 1.0000, Val Loss: 0.1746, Val Acc: 0.9615
# Epoch: 210, LR: 0.008941, Train Loss: 0.0225, Train Acc: 1.0000, Val Loss: 0.1703, Val Acc: 0.9615
# Epoch: 220, LR: 0.008843, Train Loss: 0.0207, Train Acc: 1.0000, Val Loss: 0.1658, Val Acc: 0.9615
# Epoch: 230, LR: 0.008740, Train Loss: 0.0191, Train Acc: 1.0000, Val Loss: 0.1625, Val Acc: 0.9615
# Epoch: 240, LR: 0.008634, Train Loss: 0.0178, Train Acc: 1.0000, Val Loss: 0.1589, Val Acc: 0.9615
# Epoch: 250, LR: 0.008524, Train Loss: 0.0166, Train Acc: 1.0000, Val Loss: 0.1550, Val Acc: 0.9615
# Epoch: 260, LR: 0.008411, Train Loss: 0.0156, Train Acc: 1.0000, Val Loss: 0.1509, Val Acc: 0.9615
# Epoch: 270, LR: 0.008295, Train Loss: 0.0147, Train Acc: 1.0000, Val Loss: 0.1467, Val Acc: 0.9615
# Epoch: 280, LR: 0.008175, Train Loss: 0.0139, Train Acc: 1.0000, Val Loss: 0.1427, Val Acc: 0.9615
# Epoch: 290, LR: 0.008052, Train Loss: 0.0132, Train Acc: 1.0000, Val Loss: 0.1391, Val Acc: 0.9615
# Epoch: 300, LR: 0.007926, Train Loss: 0.0126, Train Acc: 1.0000, Val Loss: 0.1356, Val Acc: 0.9615
# Epoch: 310, LR: 0.007797, Train Loss: 0.0121, Train Acc: 1.0000, Val Loss: 0.1321, Val Acc: 0.9615
# Epoch: 320, LR: 0.007666, Train Loss: 0.0116, Train Acc: 1.0000, Val Loss: 0.1286, Val Acc: 0.9615
# Epoch: 330, LR: 0.007532, Train Loss: 0.0111, Train Acc: 1.0000, Val Loss: 0.1288, Val Acc: 0.9615
# Epoch: 340, LR: 0.007395, Train Loss: 0.0107, Train Acc: 1.0000, Val Loss: 0.1286, Val Acc: 0.9615
# Epoch: 350, LR: 0.007256, Train Loss: 0.0102, Train Acc: 1.0000, Val Loss: 0.1274, Val Acc: 0.9615
# Epoch: 360, LR: 0.007115, Train Loss: 0.0097, Train Acc: 1.0000, Val Loss: 0.1268, Val Acc: 0.9615
# Epoch: 370, LR: 0.006971, Train Loss: 0.0094, Train Acc: 1.0000, Val Loss: 0.1268, Val Acc: 0.9615
# Epoch: 380, LR: 0.006826, Train Loss: 0.0091, Train Acc: 1.0000, Val Loss: 0.1254, Val Acc: 0.9615
# Epoch: 390, LR: 0.006679, Train Loss: 0.0089, Train Acc: 1.0000, Val Loss: 0.1242, Val Acc: 0.9615
# Epoch: 400, LR: 0.006530, Train Loss: 0.0087, Train Acc: 1.0000, Val Loss: 0.1232, Val Acc: 0.9615
# Epoch: 410, LR: 0.006380, Train Loss: 0.0084, Train Acc: 1.0000, Val Loss: 0.1219, Val Acc: 0.9615
# Epoch: 420, LR: 0.006228, Train Loss: 0.0081, Train Acc: 1.0000, Val Loss: 0.1196, Val Acc: 0.9615
# Epoch: 430, LR: 0.006075, Train Loss: 0.0080, Train Acc: 1.0000, Val Loss: 0.1179, Val Acc: 0.9615
# Epoch: 440, LR: 0.005921, Train Loss: 0.0078, Train Acc: 1.0000, Val Loss: 0.1167, Val Acc: 0.9615
# Epoch: 450, LR: 0.005767, Train Loss: 0.0077, Train Acc: 1.0000, Val Loss: 0.1155, Val Acc: 0.9615
# Epoch: 460, LR: 0.005611, Train Loss: 0.0076, Train Acc: 1.0000, Val Loss: 0.1145, Val Acc: 0.9615
# Epoch: 470, LR: 0.005455, Train Loss: 0.0074, Train Acc: 1.0000, Val Loss: 0.1134, Val Acc: 0.9615
# Epoch: 480, LR: 0.005298, Train Loss: 0.0073, Train Acc: 1.0000, Val Loss: 0.1124, Val Acc: 0.9615
# Epoch: 490, LR: 0.005141, Train Loss: 0.0072, Train Acc: 1.0000, Val Loss: 0.1120, Val Acc: 0.9615
# Epoch: 500, LR: 0.004984, Train Loss: 0.0071, Train Acc: 1.0000, Val Loss: 0.1108, Val Acc: 0.9615
# Epoch: 510, LR: 0.004827, Train Loss: 0.0071, Train Acc: 1.0000, Val Loss: 0.1096, Val Acc: 0.9615
# Epoch: 520, LR: 0.004670, Train Loss: 0.0070, Train Acc: 1.0000, Val Loss: 0.1085, Val Acc: 0.9615
# Epoch: 530, LR: 0.004514, Train Loss: 0.0069, Train Acc: 1.0000, Val Loss: 0.1075, Val Acc: 0.9615
# Epoch: 540, LR: 0.004358, Train Loss: 0.0068, Train Acc: 1.0000, Val Loss: 0.1066, Val Acc: 0.9615
# Epoch: 550, LR: 0.004202, Train Loss: 0.0068, Train Acc: 1.0000, Val Loss: 0.1056, Val Acc: 0.9615
# Epoch: 560, LR: 0.004048, Train Loss: 0.0067, Train Acc: 1.0000, Val Loss: 0.1047, Val Acc: 0.9615
# Epoch: 570, LR: 0.003894, Train Loss: 0.0066, Train Acc: 1.0000, Val Loss: 0.1035, Val Acc: 0.9615
# Epoch: 580, LR: 0.003741, Train Loss: 0.0066, Train Acc: 1.0000, Val Loss: 0.1029, Val Acc: 0.9615
# Epoch: 590, LR: 0.003590, Train Loss: 0.0065, Train Acc: 1.0000, Val Loss: 0.1022, Val Acc: 0.9615
# Epoch: 600, LR: 0.003440, Train Loss: 0.0065, Train Acc: 1.0000, Val Loss: 0.1014, Val Acc: 0.9615
# Epoch: 610, LR: 0.003292, Train Loss: 0.0064, Train Acc: 1.0000, Val Loss: 0.1005, Val Acc: 0.9615
# Epoch: 620, LR: 0.003145, Train Loss: 0.0064, Train Acc: 1.0000, Val Loss: 0.0997, Val Acc: 0.9615
# Epoch: 630, LR: 0.003000, Train Loss: 0.0064, Train Acc: 1.0000, Val Loss: 0.0990, Val Acc: 0.9615
# Epoch: 640, LR: 0.002857, Train Loss: 0.0063, Train Acc: 1.0000, Val Loss: 0.0990, Val Acc: 0.9615
# Epoch: 650, LR: 0.002716, Train Loss: 0.0063, Train Acc: 1.0000, Val Loss: 0.0983, Val Acc: 0.9615
# Epoch: 660, LR: 0.002577, Train Loss: 0.0063, Train Acc: 1.0000, Val Loss: 0.0981, Val Acc: 0.9615
# Epoch: 670, LR: 0.002441, Train Loss: 0.0062, Train Acc: 1.0000, Val Loss: 0.0981, Val Acc: 0.9615
# Epoch: 680, LR: 0.002308, Train Loss: 0.0062, Train Acc: 1.0000, Val Loss: 0.0978, Val Acc: 0.9615
# Epoch: 690, LR: 0.002177, Train Loss: 0.0062, Train Acc: 1.0000, Val Loss: 0.0975, Val Acc: 0.9615
# Epoch: 700, LR: 0.002048, Train Loss: 0.0061, Train Acc: 1.0000, Val Loss: 0.0974, Val Acc: 0.9615
# Epoch: 710, LR: 0.001923, Train Loss: 0.0061, Train Acc: 1.0000, Val Loss: 0.0972, Val Acc: 0.9615
# Epoch: 720, LR: 0.001801, Train Loss: 0.0061, Train Acc: 1.0000, Val Loss: 0.0970, Val Acc: 0.9615
# Epoch: 730, LR: 0.001682, Train Loss: 0.0061, Train Acc: 1.0000, Val Loss: 0.0968, Val Acc: 0.9615
# Epoch: 740, LR: 0.001566, Train Loss: 0.0061, Train Acc: 1.0000, Val Loss: 0.0966, Val Acc: 0.9615
# Epoch: 750, LR: 0.001453, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0966, Val Acc: 0.9615
# Epoch: 760, LR: 0.001344, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0963, Val Acc: 0.9615
# Epoch: 770, LR: 0.001239, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0963, Val Acc: 0.9615
# Epoch: 780, LR: 0.001137, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0961, Val Acc: 0.9615
# Epoch: 790, LR: 0.001040, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0960, Val Acc: 0.9615
# Epoch: 800, LR: 0.000946, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0959, Val Acc: 0.9615
# Epoch: 810, LR: 0.000856, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0958, Val Acc: 0.9615
# Epoch: 820, LR: 0.000770, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0957, Val Acc: 0.9615
# Epoch: 830, LR: 0.000688, Train Loss: 0.0060, Train Acc: 1.0000, Val Loss: 0.0958, Val Acc: 0.9615
# Epoch: 840, LR: 0.000611, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0956, Val Acc: 0.9615
# Epoch: 850, LR: 0.000538, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0955, Val Acc: 0.9615
# Epoch: 860, LR: 0.000469, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0955, Val Acc: 0.9615
# Epoch: 870, LR: 0.000405, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0954, Val Acc: 0.9615
# Epoch: 880, LR: 0.000345, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0954, Val Acc: 0.9615
# Epoch: 890, LR: 0.000290, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0953, Val Acc: 0.9615
# Epoch: 900, LR: 0.000240, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0953, Val Acc: 0.9615
# Epoch: 910, LR: 0.000194, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0953, Val Acc: 0.9615
# Epoch: 920, LR: 0.000153, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0953, Val Acc: 0.9615
# Epoch: 930, LR: 0.000117, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0953, Val Acc: 0.9615
# Epoch: 940, LR: 0.000086, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0952, Val Acc: 0.9615
# Epoch: 950, LR: 0.000059, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0952, Val Acc: 0.9615
# Epoch: 960, LR: 0.000037, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0952, Val Acc: 0.9615
# Epoch: 970, LR: 0.000021, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0952, Val Acc: 0.9615
# Epoch: 980, LR: 0.000009, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0952, Val Acc: 0.9615
# Epoch: 990, LR: 0.000002, Train Loss: 0.0059, Train Acc: 1.0000, Val Loss: 0.0952, Val Acc: 0.9615
# <All keys matched successfully>

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Evaluate the model
model.eval()
with torch.no_grad():
    out = model(data)  # Forward pass
    test_preds = out[data.test_mask].argmax(dim=1).cpu().numpy()  # Predicted labels
    test_labels = data.y[data.test_mask].cpu().numpy()  # True labels

    # Classification report
    report = classification_report(test_labels, test_preds, target_names=[str(i) for i in range(output_dim)])
    print("Classification Report:\n", report)

    # Confusion matrix
    cm = confusion_matrix(test_labels, test_preds)
    print("Confusion Matrix:\n", cm)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[str(i) for i in range(output_dim)], yticklabels=[str(i) for i in range(output_dim)])
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.show()
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        22
#            1       0.96      0.96      0.96        26
#            2       0.83      1.00      0.91         5
#
#     accuracy                           0.96        53
#    macro avg       0.93      0.97      0.95        53
# weighted avg       0.97      0.96      0.96        53
#
# Confusion Matrix:
#  [[21  1  0]
#  [ 0 25  1]
#  [ 0  0  5]]

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Convert PyTorch Geometric data to NetworkX
G = nx.Graph()
edge_index = data.edge_index.numpy()  # Convert edges to NumPy array
G.add_edges_from(edge_index.T)  # Add edges
G.add_nodes_from(range(data.num_nodes))  # Add nodes

# Visualize the graph
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G, seed=42)  # Generate layout
nx.draw(
    G,
    pos,
    node_color=data.y.numpy(),  # Use labels to color nodes
    cmap=plt.cm.tab10,  # Color map for distinct classes
    with_labels=True,
    node_size=50,
    edge_color="gray",
    alpha=0.7
)
plt.title("Graph Representation of Dataset")
plt.show()
